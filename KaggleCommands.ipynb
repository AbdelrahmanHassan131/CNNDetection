# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp /content/drive/MyDrive/datasetsZipped/* /content/
# !zip -s 0 /content/dataset.zip --out /content/combined.zip
# !unzip /content/combined.zip -d /content/dataset
# !rm -f /content/dataset.*
# !rm -f /content/combined.zip
# !git clone --branch ThesisModelColab https://github.com/AbdelrahmanHassan131/CNNDetection.git
# %cd /content/CNNDetection
# !python train_FFT_FreqNet_512.py --dataroot ../dataset/dataset --train_split train --val_split val --batch_size 32 --lr 0.0001 --niter 2 --num_threads 0 --name fft_freqnet_512

# %%
# !zip -r checkpoints.zip checkpoints
from google.colab import files
files.download('checkpoints.zip')

# %%
python train_FFT_WANG2020_512.py --dataroot ../dataset/dataset --train_split train --val_split val --batch_size 32 --lr 0.0001 --niter 2 --num_threads 0 --name fft_wang2020_512_train --continue_train --epoch latest
